# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set()
import pandas as pd
import numpy as np
data=pd.read_csv('red envelope.csv')
data
# Out:
#      Unnamed: 0      1      2      3      4      5      6      7  SUM  \
# 0           1.0   0.08   0.16   0.63   0.37   2.04   1.60   0.12    5
# 1           2.0   0.07   0.37   0.45   2.01   0.71   0.43   0.96    5
# 2           3.0   0.83   1.27   0.39   0.85   0.33   1.15   0.18    5
# 3           4.0   1.02   0.73   0.56   1.22   0.08   0.26   1.13    5
# 4           5.0   0.97   0.52   0.49   0.88   1.40   0.26   0.48    5
# ..          ...    ...    ...    ...    ...    ...    ...    ...  ...
# 101       102.0   1.05   1.03   0.13   0.10   1.68   0.62   0.39    5
# 102       103.0   1.07   1.21   0.72   0.90   0.10   0.50   0.50    5
# 103       104.0   0.27   0.44   0.44   1.06   1.33   1.42   0.04    5
# 104       105.0   0.40   1.43   0.57   0.19   1.03   0.38   1.00    5
# 105         NaN  72.38  84.16  74.88  71.56  67.58  71.90  82.54  525
#
#      Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# ...

# %%
np.mean(data["1"][0:105])
import matplotlib.pyplot as plt
import numpy as np


labels = ['G1', 'G2', 'G3', 'G4', 'G5','G6','G7']
men_means = [np.mean(data["1"][0:105]), np.mean(data["2"][0:105]),np.mean(data["3"][0:105]),np.mean(data["4"][0:105]),np.mean(data["5"][0:105]),np.mean(data["6"][0:105]),np.mean(data["7"][0:105])]
#women_means = [49.105835623280406, 66.31773246655867, 52.541908202915444, 48.051679459755974, 42.91273066442068,48.62419767627687,63.95965183682108]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width,)
#rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
#ax.set_ylabel('Mean')
ax.set_title('Mean of money for different orders')
#ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=3)
#ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
variance=0
for i in data["2"]:
    variance=variance+(np.mean(data["2"][0:105])-i)**2
variance/105
# Out:
# 66.31773246655867

# %%
(np.mean(data["1"][0:105])-data["1"][0])**2
# Out:
# 0.3712871111111108

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5','G6','G7']
women_means = [49.105835623280406, 66.31773246655867, 52.541908202915444, 48.051679459755974, 42.91273066442068,48.62419767627687,63.95965183682108]
x = np.arange(len(labels))
width = 0.35
fig, ax = plt.subplots()
rects2 = ax.bar(x + width/2, women_means, width)
ax.set_title('Variance of money for different orders')
ax.legend()
ax.bar_label(rects2, padding=3)
fig.tight_layout()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
from http.client import MOVED_PERMANENTLY
import random

from sqlalchemy import false, true
n=0
first=[]
second=[]
third=[]
fourth=[]
fifth=[]
sixth=[]
seventh=[]
Data=[first,second,third,fourth,fifth,sixth,seventh]
class Red:
    def __init__(self,money,people) :
        self.money=money
        self.people=people
        self.remainmoney=money
        self.remainpeople=people
        self.data=[]

    def RedEnvelop(self):
        r=random.random()
        min=0.01
        if self.remainpeople>1:
            max=self.remainmoney/self.remainpeople*2
            money=r*max
            money=round(money,2)
            if money<min:
                money=min
            self.remainpeople=self.remainpeople-1
            self.data.append(money)
            self.remainmoney=self.remainmoney-money

            return None
        if self.remainpeople<=1:
            self.data.append(round(self.remainmoney,2))
            self.remainpeople=self.remainpeople-1
            return None
        
    
    def ifnotempty(self):
        if self.remainpeople!=0:
            return true
        else:
            return false
List1=list()
List2=list()
while n<=100000:
    test=Red(5,7)
    rank=0
    while test.remainpeople!=0:
        test.RedEnvelop()
    while rank<=6:
        Data[rank].append(test.data[rank])
        rank+=1
    n+=1
    List1.append(test.data)
List1
# Out:
# [[0.24, 0.45, 1.43, 0.18, 0.7, 0.33, 1.67],
#  [0.22, 0.38, 0.29, 0.78, 2.09, 0.88, 0.36],
#  [1.16, 1.08, 1.03, 0.42, 0.25, 0.44, 0.62],
#  [0.77, 1.38, 0.02, 0.53, 1.22, 0.16, 0.92],
#  [0.55, 0.1, 1.52, 1.19, 0.92, 0.33, 0.39],
#  [1.29, 0.07, 0.62, 0.84, 0.67, 0.58, 0.93],
#  [1.12, 0.19, 1.15, 0.37, 0.03, 1.43, 0.71],
#  [0.82, 0.07, 0.02, 1.27, 1.63, 0.98, 0.21],
#  [1.23, 1.11, 0.13, 0.68, 0.94, 0.67, 0.24],
#  [0.43, 0.84, 0.76, 0.87, 0.97, 0.24, 0.89],
#  [1.34, 1.06, 0.81, 0.34, 0.67, 0.3, 0.48],
#  [1.4, 0.82, 1.04, 0.07, 0.18, 0.51, 0.98],
#  [1.31, 0.83, 0.68, 0.14, 0.72, 0.39, 0.93],
#  [1.43, 0.59, 0.27, 0.64, 1.33, 0.1, 0.64],
#  [0.44, 0.74, 0.82, 0.93, 0.01, 1.41, 0.65],
#  [0.43, 0.42, 1.65, 1.02, 0.89, 0.14, 0.45],
#  [1.24, 0.64, 0.29, 0.95, 0.54, 0.52, 0.82],
#  [1.34, 0.21, 0.12, 0.49, 1.41, 0.73, 0.7],
#  [0.79, 1.28, 0.14, 0.23, 1.6, 0.86, 0.1],
#  [0.69, 0.02, 0.52, 1.66, 1.25, 0.43, 0.43],
#  [0.48, 0.76, 0.11, 1.35, 0.47, 0.79, 1.04],
# ...

# %%
s=np.sort(List2)
N=1
n=0
list1=list()
while N<=25:
    max=N*0.2
    min=(N-1)*0.2+0.0001
    for i in s:
        if (i>=min)&(i<=max):
            n=n+1
    list1.append(n)
    n=0
    N=N+1
list1
X=np.arange(0,5,1/5)
Y=list1  
fig = plt.figure()
plt.bar(X,Y,0.1,color="orange")
plt.xlabel("Money")
plt.ylabel("Numbers of people")
plt.title("Bar chart for 100000 simulations of first order")
# Out:
# Text(0.5, 1.0, 'Bar chart for 100000 simulations of first order')

# %%
s=np.sort(List3)
N=1
n=0
list1=list()
while N<=25:
    max=N*0.2
    min=(N-1)*0.2+0.0001
    for i in s:
        if (i>=min)&(i<=max):
            n=n+1
    list1.append(n)
    n=0
    N=N+1
list1
X=np.arange(0,5,1/5)
Y=list1  
fig = plt.figure()
plt.bar(X,Y,0.1,color="orange")
plt.xlabel("Money")
plt.ylabel("Numbers of people")
plt.title("Bar chart for 100000 simulations of second order")
# Out:
# Text(0.5, 1.0, 'Bar chart for 100000 simulations of second order')

# %%
s=np.sort(List3)
N=1
n=0
list1=list()
while N<=25:
    max=N*0.2
    min=(N-1)*0.2+0.0001
    for i in s:
        if (i>=min)&(i<=max):
            n=n+1
    list1.append(n)
    n=0
    N=N+1
list1
X=np.arange(0,5,1/5)
Y=list1  
fig = plt.figure()
plt.bar(X,Y,0.1,color="orange")
plt.xlabel("Money")
plt.ylabel("Numbers of people")
plt.title("Bar chart for 100000 simulations of third order")
# Out:
# Text(0.5, 1.0, 'Bar chart for 100000 simulations of third order')

# %%
s=np.sort(List4)
N=1
n=0
list1=list()
while N<=25:
    max=N*0.2
    min=(N-1)*0.2+0.0001
    for i in s:
        if (i>=min)&(i<=max):
            n=n+1
    list1.append(n)
    n=0
    N=N+1
list1
X=np.arange(0,5,1/5)
Y=list1  
fig = plt.figure()
plt.bar(X,Y,0.1,color="orange")
plt.xlabel("Money")
plt.ylabel("Numbers of people")
plt.title("Bar chart for 100000 simulations of fourth order")
# Out:
# Text(0.5, 1.0, 'Bar chart for 100000 simulations of fourth order')

# %%
s=np.sort(List5)
N=1
n=0
list1=list()
while N<=25:
    max=N*0.2
    min=(N-1)*0.2+0.0001
    for i in s:
        if (i>=min)&(i<=max):
            n=n+1
    list1.append(n)
    n=0
    N=N+1
list1
X=np.arange(0,5,1/5)
Y=list1  
fig = plt.figure()
plt.bar(X,Y,0.1,color="orange")
plt.xlabel("Money")
plt.ylabel("Numbers of people")
plt.title("Bar chart for 100000 simulations of fifth order")
# Out:
# Text(0.5, 1.0, 'Bar chart for 100000 simulations of fifth order')

# %%
s=np.sort(List8)
N=1
n=0
list1=list()
while N<=25:
    max=N*0.2
    min=(N-1)*0.2+0.0001
    for i in s:
        if (i>=min)&(i<=max):
            n=n+1
    list1.append(n)
    n=0
    N=N+1
list1
X=np.arange(0,5,1/5)
Y=list1  
fig = plt.figure()
plt.bar(X,Y,0.1,color="orange")
plt.xlabel("Money")
plt.ylabel("Numbers of people")
plt.title("Bar chart for 100000 simulations of sixth order")
# Out:
# Text(0.5, 1.0, 'Bar chart for 100000 simulations of sixth order')

# %%
s=np.sort(List7)
N=1
n=0
list1=list()
while N<=25:
    max=N*0.2
    min=(N-1)*0.2+0.0001
    for i in s:
        if (i>=min)&(i<=max):
            n=n+1
    list1.append(n)
    n=0
    N=N+1
list1
X=np.arange(0,5,1/5)
Y=list1  
fig = plt.figure()
plt.bar(X,Y,0.1,color="orange")
plt.xlabel("Money")
plt.ylabel("Numbers of people")
plt.title("Bar chart for 100000 simulations of seventh order")
# Out:
# Text(0.5, 1.0, 'Bar chart for 100000 simulations of seventh order')

# %%
List3=list()
List4=list()
List5=list()
List6=list()
List7=list()
List8=list()
List9=list()
for i in List1:
    List2.append(i[0])
print(np.mean(List2))
for i in List1:
    List3.append(i[1])
print(np.mean(List3))
for i in List1:
    List4.append(i[2])
print(np.mean(List4))
for i in List1:
    List5.append(i[3])
print(np.mean(List5))
for i in List1:
    List6.append(i[4])
print(np.mean(List6))
for i in List1:
    List8.append(i[5])
print(np.mean(List8))

for i in List1:
    List7.append(i[6])
print(np.mean(List7))
# Out:
# 0.7154880451195487
# 0.7151863481365187
# 0.711010989890101
# 0.71359946400536
# 0.7171244287557125
# 0.7134681653183468
# 0.7141225587744122

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5','G6','G7']
men_means =[0.7152035479645202,0.723048695130487,0.7137386261373863,0.7130867691323086,0.7152362476375236,0.7149324506754933,0.7149860501394986]
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width,)
ax.set_title('Mean of money for different orders')
ax.legend()

ax.bar_label(rects1, padding=3)
#ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
variance=0
for i in List2:
    variance=variance+(np.mean(List2)-i)**2
variance/100000
# Out:
# 0.01700084236376354

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5','G6','G7']
men_means =[0.7152035479645202,0.723048695130487,0.7137386261373863,0.7144655534446556,0.7118888111188881,0.7161233876612338,0.7114138586141385]
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width,)
ax.set_title('Mean of money for different orders')
ax.legend()

ax.bar_label(rects1, padding=3)
#ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
variance=0
for i in List7:
    variance=variance+(np.mean(List7)-i)**2
variance/10000
# Out:
# 0.28992339688630964

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5','G6','G7']
women_means = [0.17000842363763538, 0.17574206150585314, 0.1863208122117824, 0.2006949389931041,0.225025122078793,0.2885130121927779,0.28992339688630964]
x = np.arange(len(labels))
width = 0.35
fig, ax = plt.subplots()
rects2 = ax.bar(x + width/2, women_means, width)
ax.set_title('Variance of money for different orders')
ax.legend()
ax.bar_label(rects2, padding=3)
fig.tight_layout()

plt.show()
# Out:
# No handles with labels found to put in legend.
